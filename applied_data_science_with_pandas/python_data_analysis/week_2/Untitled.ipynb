# %%
import pandas as pd

# %%
pd.Series?

# %%
animals = ['tiger', 'bear', 'moose']

# %%
animals
# Out:
# ['tiger', 'bear', 'moose']

# %%
pd.Series(animals)
# Out:
# 0    tiger
# 1     bear
# 2    moose
# dtype: object

# %%
numbers = [1, 2, 3, 4]

# %%
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
animals = ['Tiger', 'Bear', None]

# %%
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2     None
# dtype: object

# %%
numbers = [1, 4, None]

# %%
pd.Series(numbers)
# Out:
# 0    1.0
# 1    4.0
# 2    NaN
# dtype: float64

# %%
pd.nan == False
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-6b36188490b2> in <module>()
# ----> 1 pd.nan == False
#
# AttributeError: module 'pandas' has no attribute 'nan'

# %%
import numpy as np

# %%
np.nan == None
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Taekwondo': 'South Koria'}

# %%
a = pd.Series(sports)

# %%
a
# Out:
# Archery           Bhutan
# Golf            Scotland
# Taekwondo    South Koria
# dtype: object

# %%
a.index
# Out:
# Index(['Archery', 'Golf', 'Taekwondo'], dtype='object')

# %%
s = pd.Series(['Tiger', 'Bear', 'Moose'], index = ['India', 'America', 'Canada'])

# %%
s
# Out:
# India      Tiger
# America     Bear
# Canada     Moose
# dtype: object

# %%
t = pd.Series(['Tiger', 'Bear', 'Moose'], index = ['Bangladesh', None, None])

# %%
t
# Out:
# Bangladesh    Tiger
# NaN            Bear
# NaN           Moose
# dtype: object

# %%
s = pd.Series([100.00, 120.00, 101.00, 3.00])

# %%
s
# Out:
# 0    100.0
# 1    120.0
# 2    101.0
# 3      3.0
# dtype: float64

# %%
total = 0
for i in s:
    total += i
print(total)
# Out:
# 324.0

# %%
import numpy as np

# %%
total = np.sum(s)

# %%
total
# Out:
# 324.0

# %%
s = pd.Series(np.random.randint(0, 1000, 10000))

# %%
s.head()
# Out:
# 0    707
# 1    308
# 2    699
# 3    121
# 4    800
# dtype: int64

# %%
len(s)
# Out:
# 10000

# %%
# %%timeit -n 100
summary = 0
for item in s:
    summary += item
# Out:
# 100 loops, best of 3: 1.2 ms per loop

# %%
# %%timeit -n 100
summary = np.sum(s)
# Out:
# 100 loops, best of 3: 141 µs per loop

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0, 1000, 10000))
s += 2
# Out:
# 10 loops, best of 3: 366 µs per loop

# %%
a = pd.Series([1, 2, 3])
a.loc['Animal'] = 'Bears'

# %%
a
# Out:
# 0             1
# 1             2
# 2             3
# Animal    Bears
# dtype: object

# %%
original_sports = pd.Series({'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Taekwondo': 'South Koria'})

# %%
cricket_loving_countries = pd.Series(['Australia', 
                                      'Barbadose', 
                                      'Pakistan', 
                                      'England'], 
                                     index = ['Cricket', 
                                              'Cricket', 
                                              'Cricket', 
                                              'Cricket'])

# %%
all_countries = original_sports.append(cricket_loving_countries)

# %%
original_sports
# Out:
# Archery           Bhutan
# Golf            Scotland
# Taekwondo    South Koria
# dtype: object

# %%
cricket_loving_countries
# Out:
# Cricket    Australia
# Cricket    Barbadose
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Taekwondo    South Koria
# Cricket        Australia
# Cricket        Barbadose
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
purchase_1 = pd.Series({'name': 'Chris',
                       'Item Purchased': 'Dog food',
                       'Costs': 22.50})

# %%
purchase_2 = pd.Series({'name': 'Kevin',
                       'Item Purchased': 'Kitty Litters',
                       'Costs': 2.5})

# %%
purchase_3 = pd.Series({'name': 'Vinod',
                       'Item Purchased': 'Bird Seed',
                       'Costs': 5.0})

# %%
df = pd.DataFrame([purchase_1, purchase_2, purchase_3],
                 index = ['Store 1', 'Store 1', 'Store 2'])

# %%
df.head()
# Out:
#          Costs Item Purchased   name
# Store 1   22.5       Dog food  Chris
# Store 1    2.5  Kitty Litters  Kevin
# Store 2    5.0      Bird Seed  Vinod

# %%
df.loc['Store 2']
# Out:
# Costs                     5
# Item Purchased    Bird Seed
# name                  Vinod
# Name: Store 2, dtype: object

# %%
type(df.loc['Store 1'])
# Out:
# pandas.core.frame.DataFrame

# %%
df['Item Purchased']
# Out:
# Store 1         Dog food
# Store 1    Kitty Litters
# Store 2        Bird Seed
# Name: Item Purchased, dtype: object

# %%
df.loc['Store 1', 'Costs']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Costs, dtype: float64

# %%
df.T
# Out:
#                  Store 1        Store 1    Store 2
# Costs               22.5            2.5          5
# Item Purchased  Dog food  Kitty Litters  Bird Seed
# name               Chris          Kevin      Vinod

# %%
df.T.loc['Costs']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2       5
# Name: Costs, dtype: object

# %%
df['Costs']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Costs, dtype: float64

# %%
df.loc['Store 1']['Costs']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Costs, dtype: float64

# %%
df.loc[:, ['name', 'Costs']]
# Out:
#           name  Costs
# Store 1  Chris   22.5
# Store 1  Kevin    2.5
# Store 2  Vinod    5.0

# %%
df['Location'] = None

# %%
df
# Out:
#          Costs Item Purchased   name Location
# Store 1   22.5       Dog food  Chris     None
# Store 1    2.5  Kitty Litters  Kevin     None
# Store 2    5.0      Bird Seed  Vinod     None

# %%
df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

names_ids = df.index.str.split('\s\(') # split the index by '('

df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df = df.drop('Totals')
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %%
df.iloc[0]
# Out:
# # Summer           13
# Gold                0
# Silver              0
# Bronze              2
# Total               2
# # Winter            0
# Gold.1              0
# Silver.1            0
# Bronze.1            0
# Total.1             0
# # Games            13
# Gold.2              0
# Silver.2            0
# Bronze.2            2
# Combined total      2
# ID                AFG
# Name: Afghanistan, dtype: object

# %%
df['Gold'] > 0
# Out:
# Afghanistan                         False
# Algeria                              True
# Argentina                            True
# Armenia                              True
# Australasia                          True
# Australia                            True
# Austria                              True
# Azerbaijan                           True
# Bahamas                              True
# Bahrain                             False
# Barbados                            False
# Belarus                              True
# Belgium                              True
# Bermuda                             False
# Bohemia                             False
# Botswana                            False
# Brazil                               True
# British West Indies                 False
# Bulgaria                             True
# Burundi                              True
# Cameroon                             True
# Canada                               True
# ...

# %%
only_gold = df.where(df['Gold'] > 0)

# %%
only_gold.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan       NaN   NaN     NaN     NaN    NaN       NaN     NaN
# Algeria          12.0   5.0     2.0     8.0   15.0       3.0     0.0
# Argentina        23.0  18.0    24.0    28.0   70.0      18.0     0.0
# Armenia           5.0   1.0     2.0     9.0   12.0       6.0     0.0
# Australasia       2.0   3.0     4.0     5.0   12.0       0.0     0.0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan       NaN       NaN      NaN      NaN     NaN       NaN       NaN
# Algeria           0.0       0.0      0.0     15.0     5.0       2.0       8.0
# Argentina         0.0       0.0      0.0     41.0    18.0      24.0      28.0
# Armenia           0.0       0.0      0.0     11.0     1.0       2.0       9.0
# Australasia       0.0       0.0      0.0      2.0     3.0       4.0       5.0
#
#              Combined total   ID
# Afghanistan             NaN  NaN
# ...

# %%
only_gold['Gold'].count()
# Out:
# 99

# %%
df['Gold'].count()
# Out:
# 146

# %%
only_gold.dropna()
# Out:
#                        # Summer   Gold  Silver  Bronze   Total  # Winter  \
# Algeria                    12.0    5.0     2.0     8.0    15.0       3.0
# Argentina                  23.0   18.0    24.0    28.0    70.0      18.0
# Armenia                     5.0    1.0     2.0     9.0    12.0       6.0
# Australasia                 2.0    3.0     4.0     5.0    12.0       0.0
# Australia                  25.0  139.0   152.0   177.0   468.0      18.0
# Austria                    26.0   18.0    33.0    35.0    86.0      22.0
# Azerbaijan                  5.0    6.0     5.0    15.0    26.0       5.0
# Bahamas                    15.0    5.0     2.0     5.0    12.0       0.0
# Belarus                     5.0   12.0    24.0    39.0    75.0       6.0
# Belgium                    25.0   37.0    52.0    53.0   142.0      20.0
# Brazil                     21.0   23.0    30.0    55.0   108.0       7.0
# Bulgaria                   19.0   51.0    85.0    78.0   214.0      19.0
# ...

# %%
only_gold = df[df['Gold'] > 0]

# %%
only_gold.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
# Australia          25   139     152     177    468        18       5
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
# Australia           3         4       12       43     144       155       181
#
#              Combined total   ID
# Algeria                  15  ALG
# ...

# %%
df[(df['Gold'] > 0) | (df['Gold.1'] > 0)]
# Out:
#                        # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria                      12     5       2       8     15         3
# Argentina                    23    18      24      28     70        18
# Armenia                       5     1       2       9     12         6
# Australasia                   2     3       4       5     12         0
# Australia                    25   139     152     177    468        18
# Austria                      26    18      33      35     86        22
# Azerbaijan                    5     6       5      15     26         5
# Bahamas                      15     5       2       5     12         0
# Belarus                       5    12      24      39     75         6
# Belgium                      25    37      52      53    142        20
# Brazil                       21    23      30      55    108         7
# Bulgaria                     19    51      85      78    214        19
# ...

# %%
df['Gold'].min()
# Out:
# 0

# %%
max_gold = df.loc[df['Gold'].idxmax()]

# %%
df['Gold'].idxmin()
# Out:
# 'Afghanistan'

# %%
df['max_gold'] = df['Gold'] - df['Gold.1']

# %%
(df['Gold'] - df['Gold.1']).idxmax()
# Out:
# 'United States'

# %%
df = df[(df['Gold'] > 0) | (df['Gold.1'] > 0)]

# %%
df['Gold'] + df['Gold.1']
# Out:
# Algeria                     5
# Argentina                  18
# Armenia                     1
# Australasia                 3
# Australia                 144
# Austria                    77
# Azerbaijan                  6
# Bahamas                     5
# Belarus                    18
# Belgium                    38
# Brazil                     23
# Bulgaria                   52
# Burundi                     1
# Cameroon                    3
# Canada                    121
# Chile                       2
# China                     213
# Colombia                    2
# Costa Rica                  1
# Croatia                    10
# Cuba                       72
# Czech Republic             21
# Czechoslovakia             51
# Denmark                    43
# Dominican Republic          3
# Ecuador                     1
# Egypt                       7
# Estonia                    13
# Ethiopia                   21
# Finland                   143
#                          ...
# ...

# %%
(df['Gold'] - df['Gold.1'])/(df['Gold'] + df['Gold.1'])
# Out:
# Algeria                  1.000000
# Argentina                1.000000
# Armenia                  1.000000
# Australasia              1.000000
# Australia                0.930556
# Austria                 -0.532468
# Azerbaijan               1.000000
# Bahamas                  1.000000
# Belarus                  0.333333
# Belgium                  0.947368
# Brazil                   1.000000
# Bulgaria                 0.961538
# Burundi                  1.000000
# Cameroon                 1.000000
# Canada                  -0.024793
# Chile                    1.000000
# China                    0.887324
# Colombia                 1.000000
# Costa Rica               1.000000
# Croatia                  0.200000
# Cuba                     1.000000
# Czech Republic           0.333333
# Czechoslovakia           0.921569
# Denmark                  1.000000
# Dominican Republic       1.000000
# Ecuador                  1.000000
# Egypt                    1.000000
# ...

# %%
((df['Gold'] - df['Gold.1'])/(df['Gold'] + df['Gold.1'])).idxmax()
# Out:
# 'Algeria'

# %%
df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

# %%
df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

names_ids = df.index.str.split('\s\(') # split the index by '('

df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df = df.drop('Totals')
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %%
if df['Gold'] > 0:
    df['Points'] = df['Gold'] * 3
elif df['Silver'] > 0:
    df['Points'] = df['Silver'] * 2
elif df['Bronze'] > 0:
    df['Points'] = df['Bronze'] * 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-7aa456498193> in <module>()
# ----> 1 if df['Gold'] > 0:
#       2     df['Points'] = df['Gold'] * 3
#       3 elif df['Silver'] > 0:
#       4     df['Points'] = df['Silver'] * 2
#       5 elif df['Bronze'] > 0:
#
# /home/salayhin/anaconda3/envs/python_3.5/lib/python3.5/site-packages/pandas/core/generic.py in __nonzero__(self)
#     890         raise ValueError("The truth value of a {0} is ambiguous. "
#     891                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 892                          .format(self.__class__.__name__))
#     893
#     894     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df['Points'] = (df['Gold'] * 3) + (df['Silver'] * 2) + (df['Bronze'] * 1  )

# %%
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID  Points
# ...

# %%
census_df = pd.read_csv('census.csv')

# %%
census_df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
counties_df = census_df[census_df['SUMLEV'] == 50]
x = counties_df.groupby('STNAME').count()['SUMLEV']
ans = x.idxmax()9

# %%
x
# Out:
# STNAME
# Alabama                  67
# Alaska                   29
# Arizona                  15
# Arkansas                 75
# California               58
# Colorado                 64
# Connecticut               8
# Delaware                  3
# District of Columbia      1
# Florida                  67
# Georgia                 159
# Hawaii                    5
# Idaho                    44
# Illinois                102
# Indiana                  92
# Iowa                     99
# Kansas                  105
# Kentucky                120
# Louisiana                64
# Maine                    16
# Maryland                 24
# Massachusetts            14
# Michigan                 83
# Minnesota                87
# Mississippi              82
# Missouri                115
# Montana                  56
# Nebraska                 93
# Nevada                   17
# New Hampshire            10
# New Jersey               21
# New Mexico               33
# New York                 62
# ...
